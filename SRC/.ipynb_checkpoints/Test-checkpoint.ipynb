# %%
{x: x*2 for x in [1,2]}
# Out:
# {1: 2, 2: 4}

# %%
import numpy as np
import pandas as pd
import sklearn
import tensorflow as tf
import matplotlib.pyplot as plt
import torch

device = torch.device("mps")
# Check for TensorFlow GPU access
print(f"TensorFlow has access to the following devices:\n{tf.config.list_physical_devices()}")

# See TensorFlow version
print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow has access to the following devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow version: 2.16.1

# %%
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
! conda info --envs
# Out:
# # conda environments:
# #
# base                     /opt/anaconda3
# PythonProject            /opt/anaconda3/envs/PythonProject
# TestEnv               *  /opt/anaconda3/envs/TestEnv

# %%
! conda init
! conda activate TestEnv

# %%
import pandas as pd
import numpy as np
import tqdm as tqdm
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
import cv2

# %%
os.getcwd()
# Out:
# '/Users/pranavmoses/Desktop/5505/project/SRC'

# %%
for j in os.listdir('/Users/pranavmoses/Desktop/5505/project/tumor.v3i.folder/test'):
    print(j)
# Out:
# no_tumor
# meningioma_tumor
# glioma_tumor
# pituitary_tumor

# %%
a = ['a','b','c','d','e','f']

# %%
X_train = []
y_train = []
for i in a:
    X_train.append(i)
    y_train.append('class 01')

df = pd.DataFrame({'image': X_train, 'Class': y_train})
df.head()
# Out:
#   image     Class
# 0     a  class 01
# 1     b  class 01
# 2     c  class 01
# 3     d  class 01
# 4     e  class 01

# %%
img = '/Users/pranavmoses/Desktop/5505/project/tumor.v3i.folder/test/glioma_tumor/gg-7-_jpg.rf.142f9412490f135c551b8ea0fea42739.jpg'

# %%
img = cv2.imread(img)
plt.imshow(img)

# %%
img = cv2.resize(img,(150,150))
plt.imshow(img)

# %%
img.shape
# Out:
# (150, 150, 3)

# %%
a = ['a','b','c','a','c']

# %%
a = np.array(pd.get_dummies(a, drop_first=True, dtype=int))
a
# Out:
# array([[0, 0],
#        [1, 0],
#        [0, 1],
#        [0, 0],
#        [0, 1]])

# %%
a = np.array(a)
a
# Out:
# array([[0, 0],
#        [1, 0],
#        [0, 1],
#        [0, 0],
#        [0, 1]])

# %%
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]

print(get_available_devices())

# %%
import tensorflow as tf

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
! pip install torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 10.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 10.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 9.3 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 9.6 MB/s eta 0:00:00ta 0:00:01
# ...

# %%
import torch

# %%
# import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')
