# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

# %%
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']

# %%
def choose_random_image(folder_path):
    class_choice = random.choice(labels)
    folder_path = os.path.join(folder_path, class_choice)
    print(class_choice)
    i = random.randint(0, len(os.listdir(folder_path)))
    return os.path.join(folder_path, os.listdir(folder_path)[i])

# %%
os.chdir('/Users/pranavmoses/Desktop/5505/Project-INFO5505-Pranav Moses/project/SRC')

# %%
os.getcwd()
# Out:
# '/Users/pranavmoses/Desktop/5505/Project-INFO5505-Pranav Moses/project/SRC'

# %%
os.chdir('../')
os.chdir('tumor.v3i.folder/test/')
random_image_path = choose_random_image(os.getcwd())
print(random_image_path)
img = cv2.imread(random_image_path)
plt.imshow(img)
# Out:
# glioma_tumor
# /Users/pranavmoses/Desktop/5505/Project-INFO5505-Pranav Moses/project/tumor.v3i.folder/test/glioma_tumor/Te-gl_0257_jpg.rf.1e54358e1fbe4bed9fe4006d48e3f3ea.jpg
